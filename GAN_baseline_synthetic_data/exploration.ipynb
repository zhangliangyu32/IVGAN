# %%
import torch
from model_GAN import Generator
netG = Generator(64, 64)
netG.load_state_dict(torch.load("trained_model/final_netG.pth"))
# Out:
# <All keys matched successfully>

# %%
noise = torch.normal(0, 1, size=(10000, 64))
fake = netG(noise)
z_1 = fake[:, 0]

# %%
import matplotlib.pyplot as plt
plt.hist(z_1.detach().numpy(), 50)
# Out:
# (array([  1.,   3.,   5.,   3.,  14.,  11.,  32.,  43.,  45.,  76.,  86.,
#         122., 133., 168., 237., 219., 284., 384., 351., 425., 445., 470.,
#         524., 507., 509., 521., 503., 444., 449., 455., 403., 385., 308.,
#         302., 246., 194., 182., 116., 112.,  95.,  54.,  43.,  31.,  18.,
#          24.,  12.,   3.,   1.,   1.,   1.]),
#  array([-4.289582  , -4.040064  , -3.7905464 , -3.5410285 , -3.2915108 ,
#         -3.0419931 , -2.7924755 , -2.5429575 , -2.2934399 , -2.0439222 ,
#         -1.7944044 , -1.5448867 , -1.2953689 , -1.0458512 , -0.7963335 ,
#         -0.54681575, -0.29729798, -0.04778026,  0.20173748,  0.4512552 ,
#          0.70077294,  0.9502907 ,  1.1998085 ,  1.4493262 ,  1.698844  ,
#          1.9483616 ,  2.1978793 ,  2.447397  ,  2.696915  ,  2.9464326 ,
#          3.1959503 ,  3.445468  ,  3.6949859 ,  3.9445035 ,  4.194021  ,
#          4.443539  ,  4.6930566 ,  4.9425745 ,  5.1920924 ,  5.44161   ,
#          5.691128  ,  5.940645  ,  6.190163  ,  6.439681  ,  6.6891985 ,
#          6.9387164 ,  7.1882343 ,  7.437752  ,  7.6872697 ,  7.936787  ,
#          8.186305  ], dtype=float32),
#  <BarContainer object of 50 artists>)
